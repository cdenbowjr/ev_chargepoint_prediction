# %%
# Importing all needed packages
# %run "../src/packages/packages_for_project.py"

# Importing prepared dataframe with chargepoint information (features and target)
df = pd.read_csv("../data/interim/msoa/full_dataset_msoa.csv")

# Importing project specific functions
# %run "../src/functions/functions_for_project.py"

# Importing data dictionary
# %run "../data/raw/data_dictionary.py"

# %%
statistic_table(df,'elec_d_con','residential_mdn_ratio',0.5)
#markdown_table(df,'elec_d_con','residential_mdn_ratio',0.5)
# Out:
#                         skewed?    skew  kurtosis          mean
# nd_meters                  True  11.200   259.711  4.193916e+06
# elec_nd_con                True   7.276   134.289  2.787280e+02
# elec_nd_con_mdn            True   4.787    85.914  1.510939e+04
# residential_meter_ratio    True   3.935    36.591  1.000000e-03
# residential_ratio          True   2.562    12.362  7.401169e+04
# residential_mdn_ratio      True   1.921    12.132  2.080000e-01
# elec_d_con_mean            True   1.676     3.547  3.672728e+03
# elec_d_con                 True   1.324     3.262  1.297230e+07
# elec_d_con_mdn             True   1.258     2.884  2.929826e+03
# d_meters                   True   1.215     3.189  3.553666e+03
# elec_nd_con_mean           True   0.563     1.399  6.254738e+03

# %%
electricity = df.loc[:,'elec_d_con':'residential_mdn_ratio'].columns
for feat in electricity:
    plot_hist_box(variable=feat,dataframe=df,datadict=EV_britain())
