# %%
# Importing all needed packages
# %run "../src/packages/packages_for_project.py"

# Importing prepared dataframe with chargepoint information (features and target)
df = pd.read_csv("../data/interim/msoa/full_dataset_msoa.csv")

# Importing project specific functions
# %run "../src/functions/functions_for_project.py"

# Importing data dictionary
# %run "../data/raw/data_dictionary.py"

# %%
statistic_table(df,'num_parks','st_lengthshape',0.5)
#markdown_table(df,'num_parks','st_lengthshape',0.5)
# Out:
#                       skewed?   skew  kurtosis          mean
# num_parking              True  9.380   142.388  7.320000e-01
# train_st_distance        True  8.252    96.424  7.406300e+01
# num_train_st             True  7.580    88.579  9.860000e-01
# parking_distance         True  7.570    85.748  8.208100e+01
# supermarkets_distance    True  7.201    74.560  8.896100e+01
# st_areashape             True  6.871    88.136  1.920657e+07
# num_hotels               True  6.650    55.030  2.705000e+00
# hotel_distance           True  5.554    36.963  1.595880e+02
# gas_st_distance          True  5.537    40.848  1.144660e+02
# park_distance            True  5.351    41.310  1.223800e+02
# num_parks                True  3.536    20.246  1.259000e+00
# num_gas_st               True  3.388    17.805  1.222000e+00
# num_supermarkets         True  3.354    13.417  6.380000e-01
# st_lengthshape           True  2.794     9.577  2.107549e+04

# %%
geo_spatial = df.loc[:,'num_parks':'st_lengthshape'].columns
for feat in geo_spatial:
    plot_hist_box(variable=feat,dataframe=df,datadict=EV_britain())
