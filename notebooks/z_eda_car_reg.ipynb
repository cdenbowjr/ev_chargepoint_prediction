# %%
# Importing all needed packages
# %run "../src/packages/packages_for_project.py"

# Importing prepared dataframe with chargepoint information (features and target)
df = pd.read_csv("../data/interim/msoa/full_dataset_msoa.csv")

# Importing project specific functions
# %run "../src/functions/functions_for_project.py"

# Importing data dictionary
# %run "../data/raw/data_dictionary.py"

# %%
statistic_table(df,'no_car','growth',0.5)
#markdown_table(df,'no_car','growth',0.5)
# Out:
#              skewed?    skew  kurtosis       mean
# 2011_q4         True  21.407   536.390      1.577
# 2012_q1         True  20.501   504.063      1.595
# 2012_q2         True  19.480   467.730      1.651
# 2012_q3         True  18.068   418.449      1.722
# 2012_q4         True  15.881   341.677      1.798
# 2013_q1         True  14.706   302.515      1.874
# 2013_q2         True  13.042   247.313      1.964
# 2015_q1         True   9.827   137.634      5.049
# 2013_q3         True   9.524   134.252      2.051
# 2013_q4         True   9.000   122.931      2.172
# 2017_q1         True   8.890   106.161     14.300
# 2017_q2         True   8.865   106.220     15.662
# 2016_q4         True   8.854   104.666     12.612
# 2017_q3         True   8.750   104.477     17.395
# 2016_q3         True   8.736   101.654     11.468
# 2017_q4         True   8.545    99.529     18.954
# 2018_q1         True   8.324    94.133     20.654
# 2015_q2         True   8.240    90.919      5.778
# growth          True   8.088    86.607     28.224
# 2019_q1         True   8.075    86.663     28.128
# 2018_q4         True   8.058    85.594     26.352
# 2018_q2         True   8.045    87.176     22.439
# 2019_q2         True   7.990    85.060     29.730
# 2014_q1         True   7.934    93.484      2.387
# 2018_q3         True   7.898    82.068     24.332
# 2016_q2         True   7.850    81.942     10.137
# 2015_q3         True   7.494    73.746      6.552
# 2016_q1         True   7.305    70.521      8.937
# 2015_q4         True   7.304    68.779      7.464
# 2014_q2         True   7.066    72.463      2.678
# two_car_frac    True   6.535   148.199      0.048
# 2014_q3         True   5.615    45.361      3.304
# 2014_q4         True   5.157    34.294      4.008
# two_car_tot     True   1.849     3.367  24177.177
# no_car          True   1.609     3.286    840.412
# three+_car      True   0.748     0.360    300.149
# one_car         True   0.699     0.622   1471.496
# total_cars     False   0.403     0.244   4156.570
# two_car        False   0.303     0.055    862.297

# %%
car_ownreg = df.loc[:,'no_car':'growth'].columns
for feat in car_ownreg:
    plot_hist_box(variable=feat,dataframe=df,datadict=EV_britain())
