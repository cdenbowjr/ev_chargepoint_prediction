# %%
# Importing all needed packages
# %run "../src/packages/packages_for_project.py"

# Importing prepared dataframe with chargepoint information (features and target)
df = pd.read_csv("../data/interim/msoa/full_dataset_msoa.csv")

# Importing project specific functions
# %run "../src/functions/functions_for_project.py"

# Importing data dictionary
# %run "../data/raw/data_dictionary.py"

# %%
statistic_table(df,'walk_to_work','rail_from_holiday_nhb',0.5)
#markdown_table(df,'walk_to_work','rail_from_holiday_nhb',0.5)
# Out:
#                           skewed?    skew  kurtosis     mean
# rail_from_work               True  43.975  2534.327  283.477
# rail_to_work                 True  42.506  2411.423  283.478
# rail_to_empbus_nhb           True  40.889  2230.604   12.500
# walk_from_personbus_nhb      True  40.501  2407.323   54.766
# rail_to_personbus_nhb        True  39.955  2106.524    3.297
# ...                           ...     ...       ...      ...
# cycle_from_friends           True   1.021     2.940   29.065
# walk_from_friends            True   0.953     1.462  350.994
# cardriver_to_friends         True   0.807     1.544  777.414
# carpassenger_from_friends    True   0.750     0.605  595.595
# cardriver_from_friends      False   0.407     0.523  777.413
#
# [180 rows x 4 columns]

# %%
transport = df.loc[:,'walk_to_work':'rail_from_holiday_nhb'].columns
for feat in transport:
    plot_hist_box(variable=feat,dataframe=df,datadict=EV_britain())
